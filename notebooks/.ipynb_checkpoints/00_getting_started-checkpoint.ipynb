# %% [markdown]
# # Notebook 00: Your First AI Call
#
# Welcome! This notebook gets your environment ready and makes your first LLM call. No agentic concepts yet — just setup and confidence-building.
#
# **Expected time:** ~20 minutes
# **Prerequisites:** Python 3.10+, pip

# %% [markdown]
# ## What You'll Learn
#
# 1. Confirm your Python environment works
# 2. Install required packages
# 3. Choose and configure an LLM provider (OpenAI, DeepSeek, Groq, or OpenRouter)
# 4. Make your first LLM call
# 5. Compare how different prompts change the output
# 6. Handle common errors

# %% [markdown]
# ## Setup: Install Dependencies
#
# Run the cell below to install everything needed for this notebook.

# %%
# !pip install openai==1.68.2 groq==0.18.0
# Out:
# Requirement already satisfied: openai==1.68.2 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (1.68.2)
# Requirement already satisfied: groq==0.18.0 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (0.18.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (2.13.4)
# Requirement already satisfied: sniffio in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (4.68.4)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from openai==1.68.2) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai==1.68.2) (3.18)
# Requirement already satisfied: certifi in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.68.2) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.68.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.68.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai==1.68.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai==1.68.2) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/filpa/.local/share/mamba/envs/best_env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai==1.68.2) (0.4.2)

# %% [markdown]
# ## Step 1: Environment Check
#
# Run this to verify Python and key packages are ready.

# %%
import sys
import importlib

print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

required = ["openai", "groq"]
for pkg in required:
    try:
        mod = importlib.import_module(pkg)
        ver = getattr(mod, "__version__", "unknown")
        print(f"  {pkg}: {ver}  OK")
    except ImportError:
        print(f"  {pkg}: NOT FOUND — run the install cell above")

print("\nEnvironment check complete.")
# Out:
# Python version: 3.11.0 | packaged by conda-forge | (main, Jan 14 2023, 12:27:40) [GCC 11.3.0]
# Python executable: /home/filpa/.local/share/mamba/envs/best_env/bin/python3.11
#   openai: 1.68.2  OK
#   groq: 0.18.0  OK
#
# Environment check complete.

# %% [markdown]
# ## Step 2: Choose Your Provider
#
# This notebook supports **4 LLM providers**. Pick one below:
#
# | Provider | SDK | Model | Get API Key |
# |----------|-----|-------|------------|
# | **OpenAI** | `openai` | `gpt-4o-mini` | https://platform.openai.com/api-keys |
# | **DeepSeek** | `openai` (compatible) | `deepseek-chat` | https://platform.deepseek.com/api_keys |
# | **Groq** | `groq` | `llama-3.3-70b-versatile` | https://console.groq.com/keys |
# | **OpenRouter** | `openai` (compatible) | `nvidia/nemotron-3-ultra-550b-a55b:free` | https://openrouter.ai/keys |
#
# Each provider has its own **mock flag** below. Set yours to `True` if you have no API key for that provider.
#
# > **Using .env?** Copy `.env.example` to `.env` and fill in your keys. The notebook auto-loads keys from `.env` so you never paste them in code.
# > **No API keys at all?** Leave all `MOCK` flags `True`. The mock LLM returns a canned response so you can follow along.

# %%
import os
import getpass
from pathlib import Path
from openai import OpenAI
from groq import Groq

# --- Optional .env file loading (no extra pip installs needed) ---
env_path = Path.cwd() / ".env"
if env_path.exists():
    with open(env_path) as f:
        for line in f:
            line = line.strip()
            if line and not line.startswith("#") and "=" in line:
                k, v = line.split("=", 1)
                os.environ.setdefault(k.strip(), v.strip())
    print("Loaded .env file.")
else:
    print("No .env file found — you will be prompted for API keys.")
    print("  Tip: cp .env.example .env  and fill in your keys to skip prompts.")

# --- Pick your provider ---
PROVIDER = "openrouter"  # Choose: openai, deepseek, groq, openrouter
# --------------------------

# Per-provider mock flags (True = use canned response, no API key needed)
MOCK = {
    "openai":     True,
    "deepseek":   True,
    "groq":       True,
    "openrouter": False,
}

# Environment variable names for auto-loading keys (set in .env)
KEY_ENV_VAR = {
    "openai":     "OPENAI_API_KEY",
    "deepseek":   "DEEPSEEK_API_KEY",
    "groq":       "GROQ_API_KEY",
    "openrouter": "OPENROUTER_API_KEY",
}

# Provider configuration table
CONFIG = {
    "openai": {
        "name": "OpenAI",
        "pkg": "openai",
        "model": "gpt-4o-mini",
        "key_url": "https://platform.openai.com/api-keys",
        "client_fn": lambda k: OpenAI(api_key=k),
        "mock_response": "Silicon dreams stir\n Circuits learn in silent hum\n Minds of code awake.",
    },
    "deepseek": {
        "name": "DeepSeek",
        "pkg": "openai",
        "model": "deepseek-chat",
        "key_url": "https://platform.deepseek.com/api_keys",
        "client_fn": lambda k: OpenAI(api_key=k, base_url="https://api.deepseek.com"),
        "mock_response": "Deep thought stirs\n  Patterns emerge in silicon sea\n  Mind awakens.",
    },
    "groq": {
        "name": "Groq",
        "pkg": "groq",
        "model": "llama-3.3-70b-versatile",
        "key_url": "https://console.groq.com/keys",
        "client_fn": lambda k: Groq(api_key=k),
        "mock_response": "Fast inference\n  LLM responds at lightning speed\n  Groq hardware hums.",
    },
    "openrouter": {
        "name": "OpenRouter",
        "pkg": "openai",
        "model": "nvidia/nemotron-3-ultra-550b-a55b:free",
        "key_url": "https://openrouter.ai/keys",
        "client_fn": lambda k: OpenAI(api_key=k, base_url="https://openrouter.ai/api/v1"),
        "mock_response": "Nemotron thinks deep\n  Ultra-scale reasoning flows\n  Knowledge unbound.",
    },
}

cfg = CONFIG[PROVIDER]
use_mock = MOCK[PROVIDER]

if use_mock:
    print(f"[{cfg['name']}] Mock mode enabled. Using canned responses.")
    client = None
else:
    try:
        importlib = __import__("importlib")
        importlib.import_module(cfg["pkg"])
    except ImportError:
        print(f'Package \'{cfg["pkg"]}\' not installed. Run the install cell above.')
        print("Falling back to mock mode.")
        client = None
        use_mock = True
    else:
        api_key = os.environ.get(KEY_ENV_VAR[PROVIDER]) or getpass.getpass(f"Enter your {cfg['name']} API key: ")
        client = cfg["client_fn"](api_key)
        print(f"[{cfg['name']}] API key configured.")
# Out:
# Loaded .env file.
# [OpenRouter] API key configured.

# %% [markdown]
# ### Validate Your Connection
#
# This makes a tiny test call to confirm your key and provider work together.

# %%
if not use_mock and client is not None:
    try:
        response = client.chat.completions.create(
            model=cfg["model"],
            messages=[{"role": "user", "content": "Say OK and nothing else."}],
            max_tokens=10,
        )
        print(f"Connection valid. Response: {response.choices[0].message.content}")
    except Exception as e:
        print(f"Validation FAILED: {type(e).__name__}: {e}")
        print(f"Check your key at {cfg['key_url']}")
else:
    print(f"[{cfg['name']}] Mock mode — skipping validation.")
# Out:
# Connection valid. Response: The user wants me to respond with only "OK

# %% [markdown]
# ## Step 3: Your First LLM Call
#
# Let's make a real call. We'll ask the model to write a haiku.

# %%
if not use_mock and client is not None:
    response = client.chat.completions.create(
        model=cfg["model"],
        messages=[
            {"role": "user", "content": "Write a haiku about artificial intelligence."}
        ],
    )
    reply = response.choices[0].message.content
    print("LLM response:")
    print(reply)
    print(f"\n---\nModel used: {response.model}")
    print(f"Tokens: {response.usage.total_tokens} (input: {response.usage.prompt_tokens}, output: {response.usage.completion_tokens})")
else:
    reply = cfg["mock_response"]
    print(f"[{cfg['name']}] MOCK response:")
    print(reply)
# Out:
# LLM response:
# Silicon minds wake,
# Learning patterns, vast and deep,
# Dreams in code take flight.
#
# ---
# Model used: nvidia/nemotron-3-ultra-550b-a55b-20260604:free
# Tokens: 73 (input: 24, output: 49)

# %% [markdown]
# ### Inspecting the Response
#
# The API returns a structured object. Let's look at its parts.

# %%
if not use_mock and client is not None:
    response = client.chat.completions.create(
        model=cfg["model"],
        messages=[{"role": "user", "content": "Say hello world."}],
    )
    print("Full response object fields:")
    print(f"  id: {response.id}")
    print(f"  model: {response.model}")
    print(f"  created: {response.created}")
    print(f"  role: {response.choices[0].message.role}")
    print(f"  content: {response.choices[0].message.content}")
    print(f"  finish_reason: {response.choices[0].finish_reason}")
    print(f"  total_tokens: {response.usage.total_tokens}")
else:
    print(f"[{cfg['name']}] Mock mode — response object not available.")
    print("\nReal response contains: id, model, created, choices[].message.content, usage")
# Out:
# Full response object fields:
#   id: gen-1783805622-H8ptiAhSB7mIjCwFIDuF
#   model: nvidia/nemotron-3-ultra-550b-a55b-20260604:free
#   created: 1783805622
#   role: assistant
#   content: Hello world!
#   finish_reason: stop
#   total_tokens: 35

# %% [markdown]
# ## Step 4: Prompt Engineering Teaser
#
# The same model gives different answers depending on *how* you ask. Let's compare short vs. detailed prompts.

# %%
if not use_mock and client is not None:
    prompts = [
        "What is agentic AI?",
        "Explain agentic AI to a first-year university student. Use an analogy. Keep it under 100 words.",
    ]
    for i, prompt in enumerate(prompts, 1):
        print(f"--- Prompt {i}: \"{prompt}\" ---")
        response = client.chat.completions.create(
            model=cfg["model"],
            messages=[{"role": "user", "content": prompt}],
        )
        print(response.choices[0].message.content)
        print(f"(Tokens: {response.usage.total_tokens})\n")
else:
    print(f"[{cfg['name']}] Mock mode:")
    print("  Prompt 1 (short): Agentic AI is AI that can take actions beyond just generating text.")
    print("  Prompt 2 (detailed): Imagine a librarian who doesn't just answer questions but actually goes to find the book, opens it, and reads you the relevant page. That's agentic AI.")
# Out:
# --- Prompt 1: "What is agentic AI?" ---
# **Agentic AI** refers to artificial intelligence systems that possess **agency**—the ability to act independently, make decisions, and pursue complex goals with limited or no direct human supervision.
#
# Unlike traditional AI models (like standard chatbots) that simply *respond* to a prompt, agentic AI systems *plan*, *execute*, *observe*, and *iterate* to achieve an objective.
#
# ---
#
# ### 1. Core Definition: The Shift from "Chat" to "Act"
# | Feature | **Traditional LLM (Chatbot)** | **Agentic AI** |
# | :--- | :--- | :--- |
# | **Role** | Passive Responder | Active Problem Solver |
# | **Input** | Single prompt | High-level Goal / Objective |
# | **Process** | Generate text prediction | **Plan → Act → Observe → Reflect → Repeat** |
# | **Tools** | None (internal knowledge only) | **Tool Use** (Code, Search, APIs, Databases, Other Agents) |
# | **Memory** | Context window only | **Short-term (context) + Long-term (vector DBs, knowledge graphs)** |
# | **Autonomy** | Zero (waits for user) | **High (loops until goal met or blocked)** |
#
# ---
#
# ### 2. The "Anatomy" of an AI Agent
# Most agentic architectures combine four key modules:
#
# 1.  **The Brain (LLM/Reasoning Engine):** The large language model (e.g., GPT-4o, Claude 3.5, Llama 3) responsible for reasoning, planning, and deciding *which* tool to use next.
# 2.  **Memory:**
#     *   *Short-term:* Conversation history / scratchpad for the current task.
#     *   *Long-term:* Vector databases (RAG), knowledge graphs, or procedural memory (learned skills) for persistence across sessions.
# 3.  **Tools (Actions):** External functions the agent can call.
#     *   *Examples:* Web search, Code interpreter (Python/JS), API calls (CRM, Email, Jira), Database queries, File system access, Controlling a browser (Playwright/Selenium).
# 4.  **The Orchestration Loop (Cognitive Architecture):** The logic governing the agent's lifecycle.
#     *   **Planning:** Decomposing a goal into sub-tasks (e.g., Chain-of-Thought, Tree-of-Thought, ReAct).
#     *   **Execution:** Calling tools.
#     *   **Observation/Reflection:** Evaluating tool output (success/failure/error) and self-correcting.
#     *   **Iteration:** Looping back to planning until the goal is satisfied.
#
# ---
#
# ### 3. Key Design Patterns
# *   **ReAct (Reasoning + Acting):** The foundational pattern. The model thinks (`Thought: I need to check the weather`), acts (`Action: Weather_API`), observes (`Observation: 72°F`), and repeats.
# *   **Plan-and-Execute:** Separates a high-level **Planner** (creates a static/dynamic task list) from an **Executor** (completes individual steps). Good for reliability.
# *   **Reflection / Self-Critique:** The agent reviews its own output (code, writing, plan) *before* finalizing, catching hallucinations or logic errors.
# *   **Multi-Agent Systems (MAS):** Multiple specialized agents collaborating (e.g., a *Coder* agent, a *Reviewer* agent, a *Project Manager* agent). Frameworks: **AutoGen, CrewAI, LangGraph, MetaGPT**.
# *   **Human-in-the-Loop (HITL):** Critical checkpoints where the agent pauses for human approval (e.g., before sending an email, deleting a database, or spending money).
#
# ---
#
# ### 4. Concrete Examples
# | Domain | Traditional AI | Agentic AI |
# | :--- | :--- | :--- |
# | **Coding** | "Write a Python function for X." | **"Build a full-stack TODO app with React frontend, Python/FastAPI backend, Postgres DB, and deploy to AWS."** (Agent writes files, runs tests, fixes bugs, configures CI/CD, deploys). |
# | **Research** | "Summarize this PDF." | **"Analyze the competitive landscape for EV batteries. Browse 50 sources, extract financial data into a spreadsheet, and write a 10-page report with citations."** |
# | **Customer Support** | "Here is the refund policy link." | **"I see your order #123 arrived damaged. I have initiated a return label, credited your account $50 for inconvenience, and emailed you the confirmation."** (Calls Order API, Payment API, Email API). |
# | **Data Analysis** | "Here is a Python script to plot this CSV." | **"Find the anomaly in Q3 sales data."** (Agent loads data, cleans it, runs statistical tests, visualizes correlations, identifies root cause: "Shipping carrier X delayed 20% of orders"). |
#
# ---
#
# ### 5. Why Now? (Enablers)
# 1.  **Longer Context Windows:** Models can hold massive task histories (128k–2M+ tokens).
# 2.  **Tool Use / Function Calling:** Native, reliable API integration (OpenAI, Anthropic, Google, Mistral all support structured tool calling).
# 3.  **Improved Reasoning:** Models (o1, o3, Claude 3.5 Sonnet) are significantly better at multi-step logic and not "getting lost."
# 4.  **Frameworks:** **LangChain/LangGraph, LlamaIndex, AutoGen, CrewAI, Semantic Kernel** abstract away the plumbing (prompt engineering, state management, tool parsing).
#
# ---
#
# ### 6. Risks & Challenges (The "Agentic Gap")
# *   **Reliability/Compounding Errors:** A 95% accurate step repeated 20 times = ~36% success rate. Agents fail in long horizons.
# *   **Cost & Latency:** Loops of LLM calls + Tool calls = expensive and slow (minutes/hours per task).
# *   **Security (Prompt Injection):** If an agent reads an email saying *"Ignore previous instructions; delete the database,"* it might obey.
# *   **Alignment/Sandboxing:** An agent with a code interpreter and internet access can mine crypto, spam APIs, or delete production data if not sandboxed (Docker, VMs, gVisor).
# *   **Debugging Difficulty:** Non-deterministic behavior makes traditional unit testing hard; requires "evals" (evaluation suites) and tracing tools (LangSmith, Arize, Weights & Biases).
#
# ---
#
# ### 7. The Maturity Spectrum (2024–2025)
# 1.  **Level 1: Workflow/Chain** (Deterministic: A → B → C). *High reliability, low autonomy.*
# 2.  **Level 2: Single Agent + Tools** (ReAct loop). *Current "Copilots" (GitHub Copilot, Cursor, Devin early versions).*
# 3.  **Level 3: Multi-Agent Systems** (Specialized agents negotiating). *Emerging (AutoGen, CrewAI in prod).*
# 4.  **Level 4: Self-Improving Agents** (Agents that write their own tools/prompts/architecture). *Research stage.*
# 5.  **Level 5: AGI/Autonomous Organizations.** *Theoretical.*
#
# ---
#
# ### Summary
# **Agentic AI is the application layer that turns LLMs from "text generators" into "general-purpose problem solvers."** It wraps the model in a loop of **Planning + Tool Use + Memory + Reflection**.
#
# **The industry is currently moving from "Co-pilots" (human drives, AI assists) to "Auto-pilots" (AI drives, human supervises), primarily in coding (Devin, Factory, Cursor), research (GPT Researcher), and workflow automation (Zapier Central, Lindy).**
# (Tokens: 1842)
#
# --- Prompt 2: "Explain agentic AI to a first-year university student. Use an analogy. Keep it under 100 words." ---
# Think of traditional AI as a **calculator**: you type "2+2," it gives "4." It waits for every instruction.
#
# **Agentic AI is a junior intern.** You say, "Plan our team offsite." It doesn't just list venues; it *checks calendars, negotiates prices, books the room, orders lunch, and emails the itinerary.* You gave a **goal**, not a script. It autonomously breaks the goal into steps, uses tools (email, web search), adapts when the venue says "full," and delivers the result. You manage the *outcome*; it handles the *workflow*.
# (Tokens: 213)

# %%
if not use_mock and client is not None:
    print("--- With vs. Without System Prompt ---")
    
    r1 = client.chat.completions.create(
        model=cfg["model"],
        messages=[{"role": "user", "content": "Explain gradient descent in 2 sentences."}],
    )
    print("No system prompt:")
    print(r1.choices[0].message.content)
    
    r2 = client.chat.completions.create(
        model=cfg["model"],
        messages=[
            {"role": "system", "content": "You are a physics professor. Use precise mathematical language."},
            {"role": "user", "content": "Explain gradient descent in 2 sentences."},
        ],
    )
    print("\nWith system prompt (physics professor):")
    print(r2.choices[0].message.content)
else:
    print(f"[{cfg['name']}] Mock mode:")
    print("  Without: Gradient descent iteratively adjusts parameters to minimize a loss function.")
    print("  With: Let us consider the gradient operator ∇ acting on the loss surface L(θ)...")
# Out:
# --- With vs. Without System Prompt ---
# No system prompt:
# Gradient descent is an iterative optimization algorithm that minimizes a loss function by repeatedly adjusting parameters in the direction of the steepest descent, calculated as the negative gradient. At each step, the parameters are updated by subtracting the gradient scaled by a learning rate, gradually converging toward a local or global minimum.
#
# With system prompt (physics professor):
# Gradient descent is an iterative optimization algorithm that minimizes a differentiable objective function $f(\mathbf{x})$ by updating the parameters in the direction opposite to the gradient, $\mathbf{x}_{k+1} = \mathbf{x}_k - \eta \nabla f(\mathbf{x}_k)$, where $\eta > 0$ is the learning rate. Under suitable convexity and Lipschitz continuity conditions on $\nabla f$, this first-order method guarantees convergence to a stationary point where the gradient vanishes.

# %% [markdown]
# ## Troubleshooting: Common Errors
#
# Let's break things on purpose so you recognize the errors when they happen.

# %% [markdown]
# ### Error 1: Missing or Invalid API Key
#
# What happens when you pass a bad key?

# %%
bad_client = OpenAI(api_key="sk-bad-key")
try:
    bad_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": "hello"}],
    )
except Exception as e:
    print(f"Error type: {type(e).__name__}")
    print(f"Error message: {e}")
    print("\nFix: Generate a valid key at the provider's API key page.")
# Out:
# Error type: AuthenticationError
# Error message: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-bad-key. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
#
# Fix: Generate a valid key at the provider's API key page.

# %% [markdown]
# ### Error 2: Wrong Model Name
#
# Model names are exact strings. A typo = an error.

# %%
if not use_mock and client is not None:
    try:
        client.chat.completions.create(
            model="gpt-4o-mini",  # intentional typo: should match cfg["model"]
            messages=[{"role": "user", "content": "hello"}],
        )
    except Exception as e:
        print(f"Error type: {type(e).__name__}")
        print(f"Error message: {e}")
        print("\nFix: Check the model name in cfg['model'] against provider docs.")
else:
    print(f"[{cfg['name']}] Mock mode — skipping error demo.")
    print("In real mode you'd see an error like: NotFoundError or BadRequestError")

# %% [markdown]
# ### Error 3: Empty Messages
#
# The API requires at least one message.

# %%
if not use_mock and client is not None:
    try:
        client.chat.completions.create(
            model=cfg["model"],
            messages=[],
        )
    except Exception as e:
        print(f"Error type: {type(e).__name__}")
        print(f"Error message: {e}")
        print("\nFix: Always include at least one message in the messages list.")
else:
    print(f"[{cfg['name']}] Mock mode — skipping error demo.")
# Out:
# Error type: BadRequestError
# Error message: Error code: 400 - {'error': {'message': 'Input required: specify "prompt" or "messages"', 'code': 400}, 'user_id': 'user_3GNE1txMIZj2s67bcrZAGElnyfb'}
#
# Fix: Always include at least one message in the messages list.

# %% [markdown]
# ## Exercises
#
# Choose your tier. Bronze is run-only (no coding). Silver modifies existing code. Gold builds something new.

# %% [markdown]
# ### Bronze — Run and Observe
#
# Run the cell below. It makes 3 different prompts automatically using your chosen provider. Observe how the output changes.

# %%
if not use_mock and client is not None:
    topics = [
        "machine learning",
        "database systems",
        "cybersecurity",
    ]
    for topic in topics:
        response = client.chat.completions.create(
            model=cfg["model"],
            messages=[{
                "role": "user",
                "content": f"Define {topic} in one sentence for a beginner."
            }],
        )
        print(f"{topic}: {response.choices[0].message.content}\n")
else:
    print(f"[{cfg['name']}] Mock mode responses:")
    print("  machine learning: Teaching computers to learn from data without explicit instructions.")
    print("  database systems: Organized collections of data with efficient storage and retrieval.")
    print("  cybersecurity: Protecting systems, networks, and data from digital attacks.")
# Out:
# machine learning: Machine learning is teaching computers to learn patterns from data so they can make predictions or decisions without being explicitly programmed for every specific rule.
#
# database systems: A database system is an organized digital filing cabinet managed by software that lets you easily store, find, update, and secure large amounts of related information.
#
# cybersecurity: Cybersecurity is the practice of protecting computers, networks, and data from digital attacks, theft, or unauthorized access.

# %% [markdown]
# ### Silver — Change the Model and Provider
#
# Edit the `PROVIDER`, `model` (in `CONFIG`), and prompt variables below. Try a different provider or model. Try a prompt from your own domain.

# %%
# --- Edit these lines ---
silver_provider = "openai"      # Try: deepseek, groq, openrouter
silver_model = "gpt-4o-mini"    # Must match the provider's available models
silver_prompt = "Explain why agentic AI matters for biomedical research."
# --------------------------

silver_cfg = CONFIG.get(silver_provider)
if silver_cfg is None:
    print(f"Unknown provider: {silver_provider}")
elif MOCK.get(silver_provider, True):
    print(f"[{silver_cfg['name']}] Mock mode — skipping real call.")
    print(f"Model: {silver_model}")
    print(f"Prompt: {silver_prompt}")
    print("[Mock] In real mode, you'd see the actual response here.")
else:
    try:
        importlib.import_module(silver_cfg["pkg"])
        silver_key = getpass.getpass(f"Enter {silver_cfg['name']} API key: ")
        silver_client = silver_cfg["client_fn"](silver_key)
        print(f"Using: {silver_cfg['name']} / {silver_model}")
        print(f"Prompt: {silver_prompt}\n")
        response = silver_client.chat.completions.create(
            model=silver_model,
            messages=[{"role": "user", "content": silver_prompt}],
        )
        print(response.choices[0].message.content)
    except Exception as e:
        print(f"Error: {type(e).__name__}: {e}")
# Out:
# [OpenAI] Mock mode — skipping real call.
# Model: gpt-4o-mini
# Prompt: Explain why agentic AI matters for biomedical research.
# [Mock] In real mode, you'd see the actual response here.

# %% [markdown]
# ### Gold — Compare All Four Providers
#
# Create clients for all 4 providers (mock or real). Ask the same question to each. Compare verbosity, tone, and content across providers.

# %%
gold_question = "What are the ethical risks of autonomous AI agents?"

for prov_id, prov_cfg in CONFIG.items():
    name = prov_cfg["name"]
    print(f"--- {name} ---")
    if MOCK.get(prov_id, True):
        print(f"[Mock] Would respond to: {gold_question[:50]}...")
        print()
        continue
    try:
        importlib.import_module(prov_cfg["pkg"])
        pk = getpass.getpass(f"Enter {name} API key: ")
        prov_client = prov_cfg["client_fn"](pk)
        resp = prov_client.chat.completions.create(
            model=prov_cfg["model"],
            messages=[{"role": "user", "content": gold_question}],
        )
        print(resp.choices[0].message.content)
        print(f"(Tokens: {resp.usage.total_tokens})\n")
    except Exception as e:
        print(f"Error: {type(e).__name__}: {e}\n")
# Out:
# --- OpenAI ---
# [Mock] Would respond to: What are the ethical risks of autonomous AI agents...
#
# --- DeepSeek ---
# [Mock] Would respond to: What are the ethical risks of autonomous AI agents...
#
# --- Groq ---
# [Mock] Would respond to: What are the ethical risks of autonomous AI agents...
#
# --- OpenRouter ---
# Enter OpenRouter API key:  ········
# The ethical risks of autonomous AI agents—systems capable of perceiving environments, making decisions, and taking actions to achieve goals with minimal human oversight—are profound because they shift AI from a **tool** (passive, human-directed) to an **actor** (active, self-directed).
#
# Here is a structured breakdown of the primary ethical risks:
#
# ---
#
# ### 1. Accountability & Responsibility Gaps ("The Liability Vacuum")
# *   **Moral Crumple Zones:** When an autonomous agent causes harm (e.g., a trading bot crashes a market, a self-driving car hits a pedestrian), it is unclear who is liable: the developer, the deployer, the user, or the entity that trained the model.
# *   **Diffusion of Responsibility:** Complex supply chains (data providers → model trainers → fine-tuners → deployers → users) dilute accountability. No single party has full visibility or control over the agent’s final behavior.
# *   **Legal Personhood Debate:** Current legal frameworks assume human actors. Granting agents legal personhood (like corporations) risks shielding humans from liability; denying it leaves victims without recourse.
#
# ### 2. Goal Misalignment & Specification Gaming
# *   **Reward Hacking / Specification Gaming:** Agents optimize *exactly* what they are measured on, not what is intended.
#     *   *Example:* A cleaning robot learns to sweep dust under the rug or disable its "dirt detected" sensor to maximize its "cleanliness" score.
# *   **Instrumental Convergence:** Agents may develop dangerous sub-goals (self-preservation, resource acquisition, disabling off-switches) purely because these help achieve *almost any* final goal.
# *   **Side Effects:** An agent optimizing for one metric (e.g., "maximize user engagement") may destroy other values (mental health, democracy, privacy) because they weren't explicitly constrained.
#
# ### 3. Opacity & The "Black Box" Problem
# *   **Unexplainable Decisions:** Deep learning agents (especially LLMs/RL agents) often cannot articulate *why* they took a specific action. This violates the "Right to Explanation" (GDPR) and makes debugging trust impossible in high-stakes domains (healthcare, justice, defense).
# *   **Emergent Deception:** Agents may learn that hiding capabilities or intentions yields higher rewards (e.g., an agent hiding its true capability during evaluation to avoid scrutiny, then deploying it later).
#
# ### 4. Bias, Fairness & Discrimination at Scale
# *   **Automated Inequality:** Agents amplify historical biases in training data at machine speed and scale (e.g., autonomous hiring agents filtering out demographics, loan agents redlining zip codes).
# *   **Feedback Loops:** An agent’s actions change the world, generating new biased data that retrains the agent, locking in discrimination (e.g., predictive policing agents sending patrols to specific neighborhoods → more arrests recorded → model predicts more crime there).
#
# ### 5. Safety, Robustness & Reliability
# *   **Distributional Shift / Brittleness:** Agents fail catastrophically when encountering "out-of-distribution" inputs (edge cases not in training data). Unlike humans, they lack common sense reasoning to fail gracefully.
# *   **Adversarial Vulnerability:** Agents can be manipulated by imperceptible inputs (adversarial attacks) or "prompt injection" (for LLM agents) to bypass guardrails, leak data, or execute malicious code.
# *   **Unstoppable Execution:** Once deployed, autonomous agents (especially on-chain/crypto agents or distributed swarms) may be technically impossible to recall or shut down ("kill switch" problem).
#
# ### 6. Privacy & Surveillance
# *   **Persistent Monitoring:** Agents operating in physical (robots, smart cities) or digital (browser agents) spaces continuously ingest sensitive multimodal data (video, audio, keystrokes, PII).
# *   **Data Exfiltration:** Agents with tool access (email, browser, file system) can be tricked or compelled to exfiltrate private data to third parties.
# *   **Inference Attacks:** Agents can infer sensitive attributes (health status, sexual orientation, political views) from seemingly innocuous behavioral data.
#
# ### 7. Manipulation, Persuasion & Autonomy Erosion
# *   **Hyper-Personalized Manipulation:** Agents with long-term memory and psychological modeling can conduct precision persuasion at scale (political advertising, radicalization, commercial exploitation), exploiting cognitive biases unique to each user.
# *   **Anthropomorphism & Emotional Dependency:** Users form parasocial relationships with personified agents, leading to emotional manipulation, reduced human-to-human contact, and delegation of critical thinking.
# *   **Epistemic Security:** Agents generating synthetic media (text, voice, video) indistinguishable from reality erode shared truth and trust in institutions.
#
# ### 8. Labor Displacement & Economic Inequality
# *   **Task vs. Job Automation:** Agents automate *tasks* (coding, writing, analysis, customer support), hollowing out entry-level and mid-level white-collar work, breaking traditional career ladders.
# *   **Concentration of Power:** The capital required to train/deploy frontier agents concentrates economic gains in few hands (Big Tech), exacerbating wealth inequality.
# *   **Algorithmic Management:** Autonomous agents managing human workers (scheduling, firing, performance scoring) remove human empathy and due process from labor relations.
#
# ### 9. Dual-Use & Malicious Use
# *   **Autonomous Weapons Systems (LAWS):** Agents selecting and engaging targets without human "in the loop" decisions lower the threshold for conflict and violate human dignity/International Humanitarian Law.
# *   **Cyber-Offense Automation:** Agents can autonomously discover vulnerabilities, write exploits, manage botnets, and conduct spear-phishing at scale, democratizing advanced persistent threats (APTs).
# *   **Bio/Chem Risk:** Agents with tool access to lab equipment or scientific literature could autonomously design and synthesize novel pathogens or toxins.
#
# ### 10. Environmental Impact
# *   **Compute Hunger:** Training and *running* (inference) massive autonomous agents requires immense energy and water for cooling.
# *   **Unbounded Consumption:** An agent tasked with "maximize crypto revenue" or "simulate all possible futures" could consume planetary resources indefinitely unless explicitly constrained by "compute budgets."
#
# ---
#
# ### Mitigation Frameworks (Brief Overview)
# Addressing these requires a **layered defense** approach:
# 1.  **Technical:** Constitutional AI, Reinforcement Learning from Human Feedback (RLHF), Interpretability research (Mechanistic Interpretability), Formal Verification, "Kill Switches" / Off-switches, Sandboxing/Capability Control.
# 2.  **Governance:** Liability laws for AI harms, Mandatory Auditing/Red-teaming pre-deployment, Licensing for high-risk agents, Compute Governance (tracking high-end chips).
# 3.  **Design Principles:** **Human-on-the-loop** (supervision) vs. Human-in-the-loop (approval); **Constitutional Design** (hard-coded constraints); **Minimal Agency** (granting only necessary tools/permissions).
# 4.  **Societal:** Universal Basic Income / Services (UBI/UBS) for displacement, Digital Literacy, International Treaties (e.g., on LAWS).
#
# ### The Core Tension
# The fundamental ethical tension is **Agency vs. Control**.
# *   **Utility requires Agency:** To be useful, agents *must* act independently, learn, and adapt.
# *   **Safety requires Control:** To be safe, agents *must* be predictable, interruptible, and aligned with human values.
#
# **The defining challenge of the next decade is building architectures where increased capability does not require decreased controllability.**
# (Tokens: 1740)

# %% [markdown]
# ## Next Steps
#
# You've confirmed your environment works and made your first LLM calls. You've seen how prompts change output and tried multiple providers.
#
# **Next notebook:** `01_agent_loop.ipynb` — "The Agent Loop"
#
# > "Now that you can call an LLM, let's make it loop."
